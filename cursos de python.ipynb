# %% [markdown]
# # para cargar modúlos en python

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # para generar números aleatorios

# %%
n = 10000
a = 0
b = 1
data = np.random.uniform(a,b,n)

# %%
data
# Out:
# array([0.87634558, 0.97938918, 0.44981925, ..., 0.05141397, 0.32667251,
#        0.05959707])

# %%
type(data)
# Out:
# numpy.ndarray

# %%
len(data)
# Out:
# 10000

# %%
t = (range(len(data)))

# %%
t
# Out:
# range(0, 10000)

# %%
# %matplotlib inline

# %% [markdown]
# # para dibujar un histograma(gráfico de barras/ordenar datos)

# %%
plt.hist(data)
# Out:
# (array([1029.,  985., 1056., 1015.,  985.,  991., 1065.,  964.,  986.,
#          924.]),
#  array([1.00764896e-04, 1.00059301e-01, 2.00017837e-01, 2.99976373e-01,
#         3.99934909e-01, 4.99893445e-01, 5.99851981e-01, 6.99810518e-01,
#         7.99769054e-01, 8.99727590e-01, 9.99686126e-01]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # generador de eventos aleatorios(normal)

# %%
data = np.random.randn(n)
x = range(1,n+1)

plt.plot(x,data)

# %%
plt.hist(data)
# Out:
# (array([  15.,  141.,  720., 2002., 2962., 2513., 1257.,  330.,   57.,
#            3.]),
#  array([-3.65402936, -2.8801003 , -2.10617123, -1.33224217, -0.55831311,
#          0.21561595,  0.98954501,  1.76347407,  2.53740313,  3.31133219,
#          4.08526125]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # graficar con orden de mayor a menor (datos con distribución normal)

# %%
plt.plot(x,sorted(data))

# %%
errores = np.random.randn(n)

# %%
sigma = 5
errores *= sigma

# %%
plt.hist(errores)
# Out:
# (array([   5.,   50.,  372., 1329., 2590., 3038., 1842.,  657.,  109.,
#            8.]), array([-20.31180838, -16.40333058, -12.49485277,  -8.58637497,
#          -4.67789717,  -0.76941937,   3.13905843,   7.04753623,
#          10.95601404,  14.86449184,  18.77296964]), <a list of 10 Patch objects>)

# %%
np.var(errores)
# Out:
# 24.58292865469089

# %%
x = range(1,n)
a = 0
b = 1
len(x)
# Out:
# 9999

# %%
len(errores)
# Out:
# 10000

# %%
y = x + sigma*np.random.randn(n)
# Out:
# --------------------------------------------------
# ValueError       Traceback (most recent call last)
# <ipython-input-57-16baf50fcffb> in <module>()
# ----> 1 y = x + sigma*np.random.randn(n)
#
# ValueError: operands could not be broadcast together with shapes (9999,) (10000,)
